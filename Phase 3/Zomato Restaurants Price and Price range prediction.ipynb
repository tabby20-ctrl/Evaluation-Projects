# %% [markdown]
# # Zomato Restaurants Price Prediction

# %% [markdown]
# **project Description**
#
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# **Problem statement : In this dataset predict 2 things –**
# 1) Average Cost for two
# 2) Price range

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the dataset main file
df1=pd.read_csv("C:\\Users\\ADMIN\\Desktop\\FlipRobo\\zomato.csv",encoding='latin-1')
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
#Loading the excel file given 
df2=pd.read_excel("C:\\Users\\ADMIN\\Desktop\\FlipRobo\\Country-Code.xlsx")
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
#To display all rows
pd.set_option('display.max_columns', None)

# %%
# Merging the two DATAFRAMES 
df=pd.merge(df1,df2)
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Shape of data
df.shape
# Out:
# (9551, 22)

# %%
# Checking Columns for the database
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# Checking the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# As we can see that only Cuisines having the null values present in the dataset

# %%
# checking the % of null values present in the data
df.isnull().sum()/len(df['Cuisines'])*100
# Out:
# Restaurant ID           0.000000
# Restaurant Name         0.000000
# Country Code            0.000000
# City                    0.000000
# Address                 0.000000
# Locality                0.000000
# Locality Verbose        0.000000
# Longitude               0.000000
# Latitude                0.000000
# Cuisines                0.094231
# Average Cost for two    0.000000
# Currency                0.000000
# Has Table booking       0.000000
# Has Online delivery     0.000000
# Is delivering now       0.000000
# Switch to order menu    0.000000
# Price range             0.000000
# Aggregate rating        0.000000
# Rating color            0.000000
# Rating text             0.000000
# Votes                   0.000000
# Country                 0.000000
# dtype: float64

# %% [markdown]
# As we can see that only 0.09% are having null values we can drop  that rows

# %%
# checking the statistics of the dataset
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# **observations**
# 1. Average cost for two is having mean more than median
# 2. price range and Aggregate rating for which median is more than mean
# 3. votes mean is higher than median

# %% [markdown]
# # EDA

# %%
# plotting countries from the data and its count
sns.countplot(x=df['Country'])
print("Counts are", df['Country'].value_counts())
print(" In Percentage ", df['Country'].value_counts()/len(df['Country'])*100)
plt.xticks(rotation=90)
plt.plot()
# Out:
# Counts are India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64
#  In Percentage  India             90.587373
# United States      4.544027
# United Kingdom     0.837609
# Brazil             0.628206
# UAE                0.628206
# South Africa       0.628206
# New Zealand        0.418804
# Turkey             0.355984
# Australia          0.251283
# Phillipines        0.230342
# Indonesia          0.219872
# Singapore          0.209402
# Qatar              0.209402
# Sri Lanka          0.209402
# Canada             0.041880
# Name: Country, dtype: float64
# []

# %% [markdown]
# We can see that india share 90.59% restaurant data and 4.54% is of USA

# %%
# Checking the rating of the restaurants
rating=df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
rating
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# **Observations**
# 1. there are 2148 restaurants not rated
# 2. from 1.8 to 2.4 poor rating is shown with red colour
# 3. from 2.5 to 3.4 average rating is shown with orange colour
# 4. from 3.5 to 3.9 good rating is shown with yellow colour
# 5. from 4.0 to 4.4 very good rating with green color shown
# 6. from 4.5 to 5 Excellent rating show with dark green colour

# %%
# Ploting average rating and rating count
plt.figure(figsize=(10,6))
sns.barplot(x="Aggregate rating",y="Rating Count",data=rating)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [markdown]
# As we can see that non rated column is having considerably high count than the rated column

# %%
# plotting the ratings according to colour
plt.figure(figsize=(10,6))
sns.barplot(x="Aggregate rating",y="Rating Count",hue='Rating color',data=rating,palette=['black','red','orange','yellow','green','green'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [markdown]
# we can see that mostly ratings are given by the people are between 2.6 to 4.2

# %%
# count plot for ratings
plt.figure(figsize=(10,6))
sns.countplot(x='Rating color',data=rating,palette=['black','red','orange','yellow','green','green'])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %% [markdown]
# As we can see that the average rating with orange in colur is having 10 nos from 2.5 to 3.4

# %%
#  To check the online delivery column
sns.countplot(x=df['Has Online delivery'])
df['Has Online delivery'].value_counts()/len(df['Has Online delivery'])*100
# Out:
# No     74.337766
# Yes    25.662234
# Name: Has Online delivery, dtype: float64

# %% [markdown]
# As we can see that there are 25.66% restaurants are delivering online, but 90% data is from india so we can say that there are nearly 25% Indian restaurants are delivering online

# %%
# plotting no. of restaurants taken from top 10 cities
plt.figure(figsize=(10,6))
sns.countplot(x=df['City'],order = df['City'].value_counts().iloc[:10].index)
df['City'].value_counts().iloc[:10]/len(df['City'])*100
# Out:
# New Delhi       57.302900
# Gurgaon         11.705581
# Noida           11.307716
# Faridabad        2.627997
# Ghaziabad        0.261753
# Bhubaneshwar     0.219872
# Guwahati         0.219872
# Amritsar         0.219872
# Lucknow          0.219872
# Ahmedabad        0.219872
# Name: City, dtype: float64

# %% [markdown]
# The data is having new delhi records 57% , gurgaon and noida 11%, Faridabad 2% and rest are from various cities from India and other countries

# %%
# Analyzing the cuisines
df['Cuisines'].nunique()
# Out:
# 1825

# %%
df['Cuisines'].unique()
# Out:
# array(['French, Japanese, Desserts', 'Japanese',
#        'Seafood, Asian, Filipino, Indian', ..., 'Burger, Izgara',
#        'World Cuisine, Patisserie, Cafe', 'Italian, World Cuisine'],
#       dtype=object)

# %%
# Plotting Cuisines for top 10 
plt.figure(figsize=(10,6))
sns.countplot(x=df['Cuisines'],order = df['Cuisines'].value_counts().iloc[:10].index)
plt.xticks(rotation=90)
plt.show()
df['Cuisines'].value_counts().iloc[:10]/len(df['Cuisines'])*100
# Out:
# North Indian                      9.800021
# North Indian, Chinese             5.350225
# Chinese                           3.706418
# Fast Food                         3.706418
# North Indian, Mughlai             3.497016
# Cafe                              3.130562
# Bakery                            2.282484
# North Indian, Mughlai, Chinese    2.062611
# Bakery, Desserts                  1.779918
# Street Food                       1.560046
# Name: Cuisines, dtype: float64

# %% [markdown]
# **Observations**
# 1. As we see that there are 1825 unique values in Cuisines having different varieties that we have seen
# 2. we can see that the data cannot be directly use in machine learning it has to be featured, hence i will count the cuisines type and make the new column out of it

# %%
# To make new coloumn called Cuisine count by counting the commas 
if "CuisineCount" not in df.columns:
        df["CuisineCount"] = df['Cuisines'].str.count(',') + 1

# %%
# dropping the cuisines from the dataset the Cuisines 
df=df.drop(["Cuisines"],axis=1)

# %%
# Now plotting the new cuisines column for cout plot
plt.figure(figsize=(10,6))
sns.countplot(x=df['CuisineCount'])
df['CuisineCount'].value_counts()/len(df['CuisineCount'])*100
# Out:
# 2.0    36.059051
# 1.0    35.535546
# 3.0    19.264998
# 4.0     6.114543
# 5.0     1.717098
# 6.0     0.774788
# 7.0     0.293163
# 8.0     0.146582
# Name: CuisineCount, dtype: float64

# %% [markdown]
# As we can see that 36%, 35.5%, 19% are no. of types of cuisines having 1,2 and 3 respectively

# %%
# plotting Average cost for two 
sns.distplot(x=df["Average Cost for two"])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# the data is highly skewed towards right as we can see that average price having mean 1199 and having max value at 800000
# data is showingthat there are so many outliers present in the data and to be removed

# %%
# plotting price range
sns.distplot(x=df["Price range"])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# This can be considered as a categorical data and as this is having only for classes of price range

# %%
# plotting price range
sns.distplot(x=df["Aggregate rating"])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# As we can see that the maximum no. of aggregate rating is between  3 to 4

# %%
# Ploting Average cost for two vs aggregate rating
plt.figure(figsize=(12,6))
sns.scatterplot(x="Average Cost for two", y="Aggregate rating", hue='Price range', data=df)
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Aggregate rating'>

# %% [markdown]
# 1. The mean for average cost for two is 1199 and we can see that there are more outliers present in it.
# 2. more no. of aggregate rating is situated from 2 to 5
# 3. price range is 1 and 2

# %%
# Plotting the correlation matrix
corr_mat=df.corr()
corr_mat
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.148471  -0.226081 -0.052081
# Country Code               0.148471      1.000000  -0.698299  0.019792
# Longitude                 -0.226081     -0.698299   1.000000  0.043207
# Latitude                  -0.052081      0.019792   0.043207  1.000000
# Average Cost for two      -0.001693      0.043225   0.045891 -0.111088
# Price range               -0.134540      0.243327  -0.078939 -0.166688
# Aggregate rating          -0.326212      0.282189  -0.116818  0.000516
# Votes                     -0.147023      0.154530  -0.085101 -0.022962
# CuisineCount              -0.073993      0.012253   0.011424 -0.028517
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001693    -0.134540         -0.326212
# Country Code                      0.043225     0.243327          0.282189
# ...

# %%
# plotting the correlation matrix by heat map
plt.figure(figsize=(10,6))
sns.heatmap(corr_mat,annot=True)
# Out:
# <AxesSubplot:>

# %%
# Checking the correlation of variables with Price range
corr_mat['Price range'].sort_values(ascending=False)
# Out:
# Price range             1.000000
# Aggregate rating        0.437944
# CuisineCount            0.313101
# Votes                   0.309444
# Country Code            0.243327
# Average Cost for two    0.075083
# Longitude              -0.078939
# Restaurant ID          -0.134540
# Latitude               -0.166688
# Name: Price range, dtype: float64

# %% [markdown]
# 1. Aggregate rating is 43.79% positively correlated with the price range
# 2. Cuisines count is 31.31% positively correlated with the price range
# 3. Votes is 30.94% positively correlated with the price range
# 4. country code is 24.33% positively correlated with the price range

# %%
# Checking the correlation of variables with Average Cost for two
corr_mat['Average Cost for two'].sort_values(ascending=False)
# Out:
# Average Cost for two    1.000000
# Price range             0.075083
# Votes                   0.067783
# Aggregate rating        0.051792
# Longitude               0.045891
# Country Code            0.043225
# CuisineCount            0.013280
# Restaurant ID          -0.001693
# Latitude               -0.111088
# Name: Average Cost for two, dtype: float64

# %% [markdown]
# All the columns are having very less correlation with the target variables (Average cost of two)

# %%
# Ploting thebox plot for the dataset
df.plot(kind="box", subplots=True, layout=(4,3), figsize=(27,25),sharex=False, sharey=False)
# Out:
# Restaurant ID               AxesSubplot(0.125,0.71587;0.227941x0.16413)
# Country Code             AxesSubplot(0.398529,0.71587;0.227941x0.16413)
# Longitude                AxesSubplot(0.672059,0.71587;0.227941x0.16413)
# Latitude                   AxesSubplot(0.125,0.518913;0.227941x0.16413)
# Average Cost for two    AxesSubplot(0.398529,0.518913;0.227941x0.16413)
# Price range             AxesSubplot(0.672059,0.518913;0.227941x0.16413)
# Aggregate rating           AxesSubplot(0.125,0.321957;0.227941x0.16413)
# Votes                   AxesSubplot(0.398529,0.321957;0.227941x0.16413)
# CuisineCount            AxesSubplot(0.672059,0.321957;0.227941x0.16413)
# dtype: object

# %% [markdown]
# Votes, Average cost of two are having the outliers in the dataset, we have to deal for the same

# %% [markdown]
# # Preprocessing the data

# %% [markdown]
# **Dropping the columns which do not add any information to the model**

# %%
# Dropping the columns
df=df.drop(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City','Address','Locality', 'Locality Verbose','Longitude','Latitude','Rating color'],axis=1)

# %%
# Checking the dataframe again
df.head(5)
# Out:
#    Average Cost for two          Currency Has Table booking  \
# 0                  1100  Botswana Pula(P)               Yes
# 1                  1200  Botswana Pula(P)               Yes
# 2                  4000  Botswana Pula(P)               Yes
# 3                  1500  Botswana Pula(P)                No
# 4                  1500  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                  No                No                   No            3
# 1                  No                No                   No            3
# 2                  No                No                   No            4
# 3                  No                No                   No            4
# 4                  No                No                   No            4
#
#    Aggregate rating Rating text  Votes      Country  CuisineCount
# 0               4.8   Excellent    314  Phillipines           3.0
# ...

# %%
# Checking the Null values 
df.isnull().sum()
# Out:
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating text             0
# Votes                   0
# Country                 0
# CuisineCount            9
# dtype: int64

# %%
# Filling the Null value CuisineCount by mode method
df['CuisineCount']=df['CuisineCount'].fillna(df['CuisineCount'].mode()[0])

# %%
# Check for fill value
df['CuisineCount'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Encoding the data**

# %%
#Encoding the data
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i])
df
# Out:
#       Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 0                     1100         0                  1                    0
# 1                     1200         0                  1                    0
# 2                     4000         0                  1                    0
# 3                     1500         0                  0                    0
# 4                     1500         0                  1                    0
# ...                    ...       ...                ...                  ...
# 9546                    80        11                  0                    0
# 9547                   105        11                  0                    0
# 9548                   170        11                  0                    0
# 9549                   120        11                  0                    0
# 9550                    55        11                  0                    0
#
# ...

# %%
# Checking the correlation again by heat map
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations**
# 1. There is no multicollinearity present in the database as no two input variable are having strong correlation between each other
# 2. Agrregate rating, cuisinesCount, and votes are correlated with price range
# 3. No column is correlated with average cost for two
# 4. Dropping the Switch to order menu columns as this column is having only one value i.e. '0'

# %%
# Checking for the Switch to order menu column for the data
df['Switch to order menu'].unique()
# Out:
# array([0])

# %%
# dropping the Column Switch to order menu
df=df.drop(['Switch to order menu'],axis=1)

# %% [markdown]
# **Dealing with Outliers**

# %%
# Importing Zscore
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (9551, 11)

# %%
# Setting threshold at 3 and detecting the outliers
threshold=3
print(np.where(z>3))
# Out:
# (array([   0,    1,    2, ..., 9548, 9549, 9550], dtype=int64), array([1, 1, 1, ..., 1, 1, 1], dtype=int64))

# %%
# Removing the outlier 
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (8454, 11)

# %%
# Data Loss
loss=(9551-8454)/9551*100
loss
# Out:
# 11.48570830279552

# %% [markdown]
# We can remove the outliers from the dataset as it may affect the model and 11% is near to 10 hence, still there is enough no. of data points are available for the same

# %%
df=df1

# %%
# Checking the skewness of the dataset
df.skew()
# Out:
# Average Cost for two    3.734965
# Currency               -0.988611
# Has Table booking       2.322842
# Has Online delivery     1.027268
# Is delivering now       0.000000
# Price range             1.046263
# Aggregate rating       -0.864939
# Rating text             0.427394
# Votes                   3.714685
# Country                 7.564935
# CuisineCount            0.861943
# dtype: float64

# %% [markdown]
# Only Average cost for two, votes , Aggreagate rating are continuous columns and have to be treated for skewness removal

# %% [markdown]
# # Regression Model to Predict Average cost for two

# %% [markdown]
# **As Average cost for two becomes the target variable not to be treated for skewness**

# %%
df['Votes']=np.log(df['Votes']+1)
# df['Aggregate rating']=np.log(df['Aggregate rating']+1)

# %%
df.skew()
# Out:
# Average Cost for two    3.734965
# Currency               -0.988611
# Has Table booking       2.322842
# Has Online delivery     1.027268
# Is delivering now       0.000000
# Price range             1.046263
# Aggregate rating       -0.864939
# Rating text             0.427394
# Votes                  -0.047185
# Country                 7.564935
# CuisineCount            0.861943
# dtype: float64

# %% [markdown]
# As we can for aggregate rating we have to use other technique to

# %%
# df['Aggregate rating']=np.sqrt(df['Aggregate rating'])

# %%
# df['Aggregate rating'].skew()

# %% [markdown]
# Note: I am accepting the -0.86 skewness and proceeding further for in modelling the dataset as by np.log is giving -1.05 and np.sqrt is giving -1.11 hence keeping as it is and moving ahead
#
# And the Average Cost for two is the target variable for the regression problem.

# %%
#Splitting the datbase into inputs and output
x=df.drop(['Average Cost for two'],axis=1)
y=df['Average Cost for two']
print(x.shape)
print(y.shape)
# Out:
# (8454, 10)
# (8454,)

# %%
#importing the StandardScaler
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)
x
# Out:
# array([[-9.84765491e+00, -3.71240690e-01, -6.10613075e-01, ...,
#          1.12016768e-01, -9.36372666e+00,  9.58448831e-03],
#        [-9.84765491e+00, -3.71240690e-01, -6.10613075e-01, ...,
#          2.47079123e-02, -9.36372666e+00, -1.01607708e+00],
#        [-9.84765491e+00, -3.71240690e-01, -6.10613075e-01, ...,
#          1.26922887e+00, -9.36372666e+00,  9.58448831e-03],
#        ...,
#        [ 9.86864459e+00, -3.71240690e-01, -6.10613075e-01, ...,
#          9.61149955e-01,  6.17997134e+00,  9.58448831e-03],
#        [ 9.86864459e+00, -3.71240690e-01, -6.10613075e-01, ...,
#          9.99315684e-01,  6.17997134e+00, -1.01607708e+00],
#        [ 9.86864459e+00, -3.71240690e-01, -6.10613075e-01, ...,
#          1.25135916e+00,  6.17997134e+00,  9.58448831e-03]])

# %%
# importing Linear Regression and metrics for it
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# Finding the best Random State
maxr2=0
maxrs=0
lr=LinearRegression()
for i in range(0,200):
    print("Random State is ", i)
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(xtrain,ytrain)
    predtrain=lr.predict(xtrain)
    predtest=lr.predict(xtest)
    print('training accuracy is ', r2_score(ytrain,predtrain))
    score=r2_score(ytest,predtest)
    print('testing accuracy is ', score)
    print("\n")
    
    if score>maxr2:
        maxr2=score
        maxrs=i
        
        
print("maximum r2 score is ", maxr2 , "at random state ", maxrs)
# Out:
# Random State is  0
# training accuracy is  0.688221250984731
# testing accuracy is  0.7291528757842711
#
#
# Random State is  1
# training accuracy is  0.6887106074155294
# testing accuracy is  0.7353607559957918
#
#
# Random State is  2
# training accuracy is  0.7112205405277372
# testing accuracy is  0.6507956206110097
#
#
# Random State is  3
# training accuracy is  0.6903208874530299
# testing accuracy is  0.7285888716503652
#
#
# Random State is  4
# training accuracy is  0.6891664245517131
# testing accuracy is  0.7344736082439287
#
#
# Random State is  5
# training accuracy is  0.7069240269351585
# testing accuracy is  0.6597430775976205
#
#
# Random State is  6
# training accuracy is  0.7051884139472173
# testing accuracy is  0.6630910094432323
#
#
# Random State is  7
# training accuracy is  0.7057374698309749
# testing accuracy is  0.6672318110385488
#
#
# Random State is  8
# training accuracy is  0.6994708869149066
# testing accuracy is  0.6881736926507588
#
#
# ...

# %% [markdown]
# We have got the best random state as 121 where the testing accuracy is 0.75 and training is 0.6855

# %%
# Spliting data on the best Random state we have got
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=121)

# %%
#running that same model again for other metrics too

lr.fit(x_train,y_train)
predtrainlr=lr.predict(x_train)
predtestlr=lr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainlr))
print('testing accuracy is ', r2_score(y_test,predtestlr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestlr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestlr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestlr)))
# Out:
# training accuracy is  0.6855957034570863
# testing accuracy is  0.7576035669482655
# Mean Squared Error is  65555.91691610645
# Mean Absolute Error is  162.52247531957198
# Root Mean Squared Error is  256.03889727169667

# %%
from sklearn.model_selection import cross_val_score
#Cross validation of the lr model
for j in range(2,20):
    cv_score=cross_val_score(lr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
    print('training accuracy is ', r2_score(y_train,predtrainlr))
    print('testing accuracy is ', r2_score(y_test,predtestlr))
# Out:
# At fold  2 Mean CV score is  -4.092353400354301e+24
# training accuracy is  0.6855957034570863
# testing accuracy is  0.7576035669482655
# At fold  3 Mean CV score is  -1.7561300154321225e+23
# training accuracy is  0.6855957034570863
# testing accuracy is  0.7576035669482655
# At fold  4 Mean CV score is  -1.0886898291866411e+23
# training accuracy is  0.6855957034570863
# testing accuracy is  0.7576035669482655
# At fold  5 Mean CV score is  -4.4577833834176525e+20
# training accuracy is  0.6855957034570863
# testing accuracy is  0.7576035669482655
# At fold  6 Mean CV score is  -8.692169624380445e+19
# training accuracy is  0.6855957034570863
# testing accuracy is  0.7576035669482655
# At fold  7 Mean CV score is  -2.6981604344190136e+19
# training accuracy is  0.6855957034570863
# testing accuracy is  0.7576035669482655
# At fold  8 Mean CV score is  -3.948508072831801e+21
# training accuracy is  0.6855957034570863
# testing accuracy is  0.7576035669482655
# ...

# %%
# modelling using the Decision tree regressor
from sklearn.tree import DecisionTreeRegressor

dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
predtraindtr=dtr.predict(x_train)
predtestdtr=dtr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtraindtr))
print('testing accuracy is ', r2_score(y_test,predtestdtr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestdtr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestdtr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestdtr)))
# Out:
# training accuracy is  0.9898240492373036
# testing accuracy is  0.6726830998849465
# Mean Squared Error is  88522.5877255392
# Mean Absolute Error is  149.85223799746396
# Root Mean Squared Error is  297.52745709520525

# %%
#Cross validation of the dtr model
dtr=DecisionTreeRegressor()
for j in range(2,10):
    cvdtr=cross_val_score(dtr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cvdtr.mean())
# Out:
# At fold  2 Mean CV score is  0.6331206180651385
# At fold  3 Mean CV score is  0.6437970493962851
# At fold  4 Mean CV score is  0.6376700756471402
# At fold  5 Mean CV score is  0.5635577658346437
# At fold  6 Mean CV score is  0.5524177441370224
# At fold  7 Mean CV score is  0.5631673560655306
# At fold  8 Mean CV score is  0.5215541576677241
# At fold  9 Mean CV score is  0.5743858224555383

# %%
# Modelling with randomForestRegressor

from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
predtrainrfr=rfr.predict(x_train)
predtestrfr=rfr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainrfr))
print('testing accuracy is ', r2_score(y_test,predtestrfr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestrfr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestrfr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestrfr)))
# Out:
# training accuracy is  0.9631491505784887
# testing accuracy is  0.8221506695615626
# Mean Squared Error is  48099.20584647783
# Mean Absolute Error is  125.9048282471746
# Root Mean Squared Error is  219.31531147295172

# %%
#Cross validation of the rfr model
for j in range(2,10):
    cv_score=cross_val_score(rfr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.7423677142525709
# At fold  3 Mean CV score is  0.7566625053567796
# At fold  4 Mean CV score is  0.7533395334859997
# At fold  5 Mean CV score is  0.7205129244630628
# At fold  6 Mean CV score is  0.7088575357580428
# At fold  7 Mean CV score is  0.7073048541291049
# At fold  8 Mean CV score is  0.6960481244372361
# At fold  9 Mean CV score is  0.7013460948707274

# %%
# modelling with ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesRegressor

etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
predtrainetr=etr.predict(x_train)
predtestetr=etr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainetr))
print('testing accuracy is ', r2_score(y_test,predtestetr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestetr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestetr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestetr)))
# Out:
# training accuracy is  0.9897237120502105
# testing accuracy is  0.7875139880049123
# Mean Squared Error is  57466.66802317075
# Mean Absolute Error is  131.8808332876131
# Root Mean Squared Error is  239.72206411419612

# %%
#Cross validation of the etr model
for j in range(2,10):
    cv_score=cross_val_score(etr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.747170367238859
# At fold  3 Mean CV score is  0.7161073219994889
# At fold  4 Mean CV score is  0.7249203254718242
# At fold  5 Mean CV score is  0.682920689287282
# At fold  6 Mean CV score is  0.6802530854963358
# At fold  7 Mean CV score is  0.6860588662045412
# At fold  8 Mean CV score is  0.6589052599629459
# At fold  9 Mean CV score is  0.6762725334079626

# %%
# Modeling for gradient boosting regresssor
from sklearn.ensemble import GradientBoostingRegressor

gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
predtraingbr=gbr.predict(x_train)
predtestgbr=gbr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtraingbr))
print('testing accuracy is ', r2_score(y_test,predtestgbr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestgbr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestgbr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestgbr)))
# Out:
# training accuracy is  0.8558740856789521
# testing accuracy is  0.8479868011995219
# Mean Squared Error is  41111.84519199923
# Mean Absolute Error is  122.65702463027543
# Root Mean Squared Error is  202.76056123417894

# %%
#Cross validation of the gbr model
for j in range(2,10):
    cv_score=cross_val_score(gbr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.7563456402917796
# At fold  3 Mean CV score is  0.7593087485627669
# At fold  4 Mean CV score is  0.7687030170551752
# At fold  5 Mean CV score is  0.7251215870808266
# At fold  6 Mean CV score is  0.7384508194710421
# At fold  7 Mean CV score is  0.7471297026914913
# At fold  8 Mean CV score is  0.729963871961524
# At fold  9 Mean CV score is  0.7320088565376381

# %%
# Modeling for gradient AdaBoostRegressor
from sklearn.ensemble import AdaBoostRegressor

adr=AdaBoostRegressor()
adr.fit(x_train,y_train)
predtrainadr=adr.predict(x_train)
predtestadr=adr.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainadr))
print('testing accuracy is ', r2_score(y_test,predtestadr))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestadr))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestadr))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestadr)))
# Out:
# training accuracy is  0.7647355425088734
# testing accuracy is  0.7207971339699755
# Mean Squared Error is  75510.18658882903
# Mean Absolute Error is  152.46558324625258
# Root Mean Squared Error is  274.7911690517529

# %%
#Cross validation of the adr model
for j in range(2,10):
    cv_score=cross_val_score(adr, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.6651820713276364
# At fold  3 Mean CV score is  0.6651200819041467
# At fold  4 Mean CV score is  0.690707367869348
# At fold  5 Mean CV score is  0.6006253829765195
# At fold  6 Mean CV score is  0.6162430482637368
# At fold  7 Mean CV score is  0.613517208651628
# At fold  8 Mean CV score is  0.5895481008707878
# At fold  9 Mean CV score is  0.5768582996591766

# %% [markdown]
# **Regularization**

# %%
from sklearn.linear_model import Lasso,Ridge, ElasticNet
from sklearn.model_selection import GridSearchCV

# %%
# Doing Lasso Regularization
#HyperParameter Tunning to find out the best parameters
parameters={'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100],
            'random_state':list(range(0,10)),
            'max_iter':[10,100,1000,10000],
            'tol': [0.001,0.0001,0.00001,0.000001]}

ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'max_iter': 10, 'random_state': 0, 'tol': 0.0001}

# %%
ls=Lasso(alpha=1, max_iter=10, random_state=0, tol=0.0001)
ls.fit(x_train,y_train)
predtrainls=ls.predict(x_train)
predtestls=ls.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainls))
print('testing accuracy is ', r2_score(y_test,predtestls))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestls))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestls))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestls)))
# Out:
# training accuracy is  0.6855696328824468
# testing accuracy is  0.7582185893040645
# Mean Squared Error is  65389.58462337958
# Mean Absolute Error is  162.08899625562748
# Root Mean Squared Error is  255.71387256732785

# %%
#Cross validation of the ls model
for j in range(2,10):
    cv_score=cross_val_score(ls, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.5949654527480688
# At fold  3 Mean CV score is  0.5941043688638213
# At fold  4 Mean CV score is  0.6131377914914944
# At fold  5 Mean CV score is  0.503711640377409
# At fold  6 Mean CV score is  0.511216086767395
# At fold  7 Mean CV score is  0.5192545123738368
# At fold  8 Mean CV score is  0.4904303137509227
# At fold  9 Mean CV score is  0.5053187241996204

# %%
# Doing Ridge Regularization
#HyperParameter Tunning to find out the best parameters
parameters={'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100],
            'random_state':list(range(0,10)),
            'max_iter':[10,100,1000,10000],
            'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']}

rg=Ridge()
clf=GridSearchCV(rg,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1e-05, 'max_iter': 10, 'random_state': 4, 'solver': 'sag'}

# %%
rg=Ridge(alpha=1e-05, max_iter=10, random_state=4, solver='sag')
rg.fit(x_train,y_train)
predtrainrg=rg.predict(x_train)
predtestrg=rg.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainrg))
print('testing accuracy is ', r2_score(y_test,predtestrg))
print("Mean Squared Error is ",mean_squared_error(y_test,predtestrg))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtestrg))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtestrg)))
# Out:
# training accuracy is  0.6840797719693217
# testing accuracy is  0.7586583286650666
# Mean Squared Error is  65270.65747312552
# Mean Absolute Error is  162.6243070780433
# Root Mean Squared Error is  255.48122724209213

# %%
#Cross validation of the ls model
for j in range(2,10):
    cv_score=cross_val_score(rg, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.5573378307902594
# At fold  3 Mean CV score is  0.5812069229066805
# At fold  4 Mean CV score is  0.5974347047254387
# At fold  5 Mean CV score is  0.46732457903045405
# At fold  6 Mean CV score is  0.499971747311861
# At fold  7 Mean CV score is  0.5170695178885508
# At fold  8 Mean CV score is  0.4712274366141168
# At fold  9 Mean CV score is  0.4847762633990911

# %%
# ElasticNet Regularization
#HyperParameter Tunning to find out the best parameters
parameters={'l1_ratio':[.1,.2,.5,.7,.9,.95,.99], 
            'max_iter': [10,100,1000,10000], 
            'tol': [0.1,0.001,0.0001,0.00001,0.000001], 
            'random_state':list(range(0,10)),
            'alpha':[.00001,0.0001,0.001,0.01,0.1,1,10,100]
           }

en=ElasticNet()
clf=GridSearchCV(en,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'l1_ratio': 0.95, 'max_iter': 100, 'random_state': 0, 'tol': 1e-06}

# %%
en=ElasticNet(alpha=0.1, max_iter=100, random_state=0, l1_ratio=0.95,tol=1e-06)
en.fit(x_train,y_train)
predtrainen=en.predict(x_train)
predtesten=en.predict(x_test)
print('training accuracy is ', r2_score(y_train,predtrainen))
print('testing accuracy is ', r2_score(y_test,predtesten))
print("Mean Squared Error is ",mean_squared_error(y_test,predtesten))
print("Mean Absolute Error is ",mean_absolute_error(y_test,predtesten))
print("Root Mean Squared Error is ",np.sqrt(mean_squared_error(y_test,predtesten)))
# Out:
# training accuracy is  0.6855758890434388
# testing accuracy is  0.7579932759553886
# Mean Squared Error is  65450.52043410884
# Mean Absolute Error is  161.82788530691963
# Root Mean Squared Error is  255.83299324776084

# %%
#Cross validation of the ls model
for j in range(2,10):
    cv_score=cross_val_score(en, x, y, cv=j)
    print('At fold ', j , "Mean CV score is ", cv_score.mean())
# Out:
# At fold  2 Mean CV score is  0.5887108559285896
# At fold  3 Mean CV score is  0.5836407228100909
# At fold  4 Mean CV score is  0.6019040494591207
# At fold  5 Mean CV score is  0.49299933910045796
# At fold  6 Mean CV score is  0.49929480288288425
# At fold  7 Mean CV score is  0.5076876767337246
# At fold  8 Mean CV score is  0.47903455250752697
# At fold  9 Mean CV score is  0.49444846757456773

# %% [markdown]
# **Selecting the best model**
# 1. Comparing all models on the r2score it is seen that the Gradient Boosting Regressor is giving an test accuracy of 84.79, training accuracy as 85.58 and and cross val score of 76.87 at fold 4
# 2. cross val scores of all models have compared at fold 4 and it is found to be Gradient boostting is giving and higher accuracy

# %% [markdown]
# **Hyper parameter Tunning**

# %%
# Hyperparameter tunning for gradient boosting regressor
parameter = {'learning_rate': [0.01,0.02,0.03,0.04],
             'n_estimators' : [100,500,1000, 1500],
             'max_depth'    : [4,6,8,10]
                 }
 
model = GradientBoostingRegressor ()

gcv = GridSearchCV(model,parameter,cv=4,n_jobs=-1).fit(x_train,y_train.values.ravel())

gcv.best_params_
# Out:
# {'learning_rate': 0.04, 'max_depth': 4, 'n_estimators': 100}

# %%
gcv.best_estimator_
# Out:
# GradientBoostingRegressor(learning_rate=0.04, max_depth=4)

# %%
# Checking score with best parameter
final_model=GradientBoostingRegressor(learning_rate=0.04,max_depth=4,n_estimators=100)
final_model.fit(x_train,y_train)
predfinal=final_model.predict(x_test)
print('Final Accuracy is with Gradient Boosting Regressor is  = ',r2_score(y_test,predfinal))
# Out:
# Final Accuracy is with Gradient Boosting Regressor is  =  0.8561520094892433

# %%
#Importing Job lib for saving the model
import joblib
joblib.dump(gcv.best_estimator_, "Zomato Average price for two prediction.pkl")
# Out:
# ['Zomato Average price for two prediction.pkl']

# %%
# Conclusion
a=np.array(y_test)
predicted=np.array(predfinal)
df_con=pd.DataFrame({'Original':a,'Predicted':predfinal}, index=range(len(a)))
df_con
# Out:
#       Original    Predicted
# 0          600   594.728151
# 1          400   372.093935
# 2          450   280.865535
# 3          800   606.065982
# 4          800   620.029175
# ...        ...          ...
# 1686       400   352.790691
# 1687       200   258.682441
# 1688       500   576.323853
# 1689      1100  1420.370007
# 1690       100   280.865535
#
# [1691 rows x 2 columns]

# %% [markdown]
# # Classification model for Price range Prediction

# %%
# Calling the database to see
df
# Out:
#       Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 516                     20         2                  0                    0
# 517                     20         2                  0                    0
# 518                     20         2                  0                    0
# 519                      7         2                  0                    0
# 520                     20         2                  0                    0
# ...                    ...       ...                ...                  ...
# 9332                    40         6                  0                    0
# 9333                    80         6                  0                    0
# 9334                    70         6                  0                    0
# 9335                   110         6                  0                    0
# 9336                    90         6                  0                    0
#
# ...

# %%
# Checking the skewness of the data
df.skew()
# Out:
# Average Cost for two    3.734965
# Currency               -0.988611
# Has Table booking       2.322842
# Has Online delivery     1.027268
# Is delivering now       0.000000
# Price range             1.046263
# Aggregate rating       -0.864939
# Rating text             0.427394
# Votes                   3.714685
# Country                 7.564935
# CuisineCount            0.861943
# dtype: float64

# %%
# removing skewness from Average Cost for two
df['Average Cost for two']=np.log(df['Average Cost for two']+1)

# %%
df['Average Cost for two'].skew()
# Out:
# -0.4768456396466655

# %%
# Splitting the data into inputs and output
X=df.drop(['Price range'],axis=1)
Y=df['Price range']
print(X.shape)
print(Y.shape)
# Out:
# (8454, 10)
# (8454,)

# %%
#importing the StandardScaler
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X=ss.fit_transform(X)
X
# Out:
# array([[-3.86856975e+00, -9.84765491e+00, -3.71240690e-01, ...,
#         -3.71019366e-01, -9.36372666e+00,  9.58448831e-03],
#        [-3.86856975e+00, -9.84765491e+00, -3.71240690e-01, ...,
#         -3.93450633e-01, -9.36372666e+00, -1.01607708e+00],
#        [-3.86856975e+00, -9.84765491e+00, -3.71240690e-01, ...,
#          8.17837787e-01, -9.36372666e+00,  9.58448831e-03],
#        ...,
#        [-2.32300741e+00,  9.86864459e+00, -3.71240690e-01, ...,
#          2.23409211e-01,  6.17997134e+00,  9.58448831e-03],
#        [-1.75605686e+00,  9.86864459e+00, -3.71240690e-01, ...,
#          2.79487378e-01,  6.17997134e+00, -1.01607708e+00],
#        [-2.00812439e+00,  9.86864459e+00, -3.71240690e-01, ...,
#          7.72975253e-01,  6.17997134e+00,  9.58448831e-03]])

# %% [markdown]
# **Balancing the dataset**

# %%
Y.value_counts()
# Out:
# 1    4274
# 2    2780
# 3    1017
# 4     383
# Name: Price range, dtype: int64

# %%
# Importing Libraries for it 
from imblearn.over_sampling import SMOTE
sm=SMOTE()
X,Y=sm.fit_resample(X,Y)
Y.value_counts()
# Out:
# 2    4274
# 1    4274
# 3    4274
# 4    4274
# Name: Price range, dtype: int64

# %% [markdown]
# **Modelling the dataset for classification**

# %%
# importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
lg=LogisticRegression()

# %%
# Finding the random state
maxaccu=0
maxrs=0
for i in range(1,100):
    print("At Random State ", i)
    Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=.20, random_state=i)
    lg.fit(Xtrain,Ytrain)
    predlg=lg.predict(Xtest)
    trainlg=lg.predict(Xtrain)
    acc=accuracy_score(Ytest,predlg)
    accu=accuracy_score(Ytrain,trainlg)
    print('testing accuracy', acc, 'randon state',i)
    print('Training Accuracy', accu, 'random state', i)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
        print('max accuracy', maxaccu , 'max_random_state', maxrs)
# Out:
# At Random State  1
# testing accuracy 0.8991228070175439 randon state 1
# Training Accuracy 0.9036999122550453 random state 1
# max accuracy 0.8991228070175439 max_random_state 1
# At Random State  2
# testing accuracy 0.9084795321637427 randon state 2
# Training Accuracy 0.9051623281661304 random state 2
# max accuracy 0.9084795321637427 max_random_state 2
# At Random State  3
# testing accuracy 0.9073099415204678 randon state 3
# Training Accuracy 0.9079409183971922 random state 3
# At Random State  4
# testing accuracy 0.9049707602339181 randon state 4
# Training Accuracy 0.9026762211172857 random state 4
# At Random State  5
# testing accuracy 0.9029239766081871 randon state 5
# Training Accuracy 0.9053816905527932 random state 5
# At Random State  6
# testing accuracy 0.8929824561403509 randon state 6
# Training Accuracy 0.9132787364726528 random state 6
# At Random State  7
# testing accuracy 0.9181286549707602 randon state 7
# ...

# %%
# Checking for the Max. Accuracy at Random State
print('max accuracy', maxaccu , 'max_random_state', maxrs)
# Out:
# max accuracy 0.9181286549707602 max_random_state 7

# %%
# train test split for the data with suggested random state
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.20,random_state=7)

# %%
# Checking score again for the the lr model 
lg=LogisticRegression()
lg.fit(X_train,Y_train)
predlg=lg.predict(X_test)
predtrain=lg.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predlg))
print(confusion_matrix(Y_test,predlg))
print(classification_report(Y_test,predlg))
# Out:
# Training accuracy is  0.9054548113483475
# 0.9181286549707602
# [[819  44   0   0]
#  [  7 773  56   0]
#  [  5  51 705  57]
#  [  0   4  56 843]]
#               precision    recall  f1-score   support
#
#            1       0.99      0.95      0.97       863
#            2       0.89      0.92      0.91       836
#            3       0.86      0.86      0.86       818
#            4       0.94      0.93      0.94       903
#
#     accuracy                           0.92      3420
#    macro avg       0.92      0.92      0.92      3420
# weighted avg       0.92      0.92      0.92      3420

# %%
import yellowbrick
from  yellowbrick.classifier import ROCAUC

def plot_ROC_curve(model, X_train, Y_train, X_test, Y_test):

    # Creating visualization with the readable labels
    visualizer = ROCAUC(model, encoder={1:'Price range 1' , 2:'Price range 2' ,3:'Price range 3' ,4:'Price range 4'})
                                        
    # Fitting to the training data first then scoring with the test data                                    
    visualizer.fit(X_train, Y_train)
    visualizer.score(X_test, Y_test)
    visualizer.show()
    
    return visualizer

# %%
# Plotting AUC ROC for Logistic Regression
plot_ROC_curve(lg,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for LogisticRegression'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={1: 'Price range 1', 2: 'Price range 2', 3: 'Price range 3',
#                 4: 'Price range 4'},
#        estimator=LogisticRegression())

# %%
# using DecisionTreeClassifier 
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(X_train,Y_train)
preddtc=dtc.predict(X_test)
predtrain=dtc.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,preddtc))
print(confusion_matrix(Y_test,preddtc))
print(classification_report(Y_test,preddtc))
# Out:
# Training accuracy is  0.9999268792044458
# 0.966374269005848
# [[851  12   0   0]
#  [  4 806  26   0]
#  [  0  18 778  22]
#  [  0   0  33 870]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99       863
#            2       0.96      0.96      0.96       836
#            3       0.93      0.95      0.94       818
#            4       0.98      0.96      0.97       903
#
#     accuracy                           0.97      3420
#    macro avg       0.97      0.97      0.97      3420
# weighted avg       0.97      0.97      0.97      3420

# %%
# Plotting AUC ROC for Decision Tree Classifier
plot_ROC_curve(dtc,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for DecisionTreeClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={1: 'Price range 1', 2: 'Price range 2', 3: 'Price range 3',
#                 4: 'Price range 4'},
#        estimator=DecisionTreeClassifier())

# %%
# Using RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
predrf=rf.predict(X_test)
predtrain=rf.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predrf))
print(confusion_matrix(Y_test,predrf))
print(classification_report(Y_test,predrf))
# Out:
# Training accuracy is  0.9999268792044458
# 0.9871345029239766
# [[862   1   0   0]
#  [  2 830   4   0]
#  [  0  19 793   6]
#  [  0   0  12 891]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       863
#            2       0.98      0.99      0.98       836
#            3       0.98      0.97      0.97       818
#            4       0.99      0.99      0.99       903
#
#     accuracy                           0.99      3420
#    macro avg       0.99      0.99      0.99      3420
# weighted avg       0.99      0.99      0.99      3420

# %%
# Plotting AUC ROC for Random Forest Classifier
plot_ROC_curve(rf,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={1: 'Price range 1', 2: 'Price range 2', 3: 'Price range 3',
#                 4: 'Price range 4'},
#        estimator=RandomForestClassifier())

# %%
# Using SVC
from sklearn.svm import SVC
svc=SVC(probability=True)
svc.fit(X_train,Y_train)
predsvc=svc.predict(X_test)
predtrain=svc.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predsvc))
print(confusion_matrix(Y_test,predsvc))
print(classification_report(Y_test,predsvc))
# Out:
# Training accuracy is  0.9325095057034221
# 0.9426900584795321
# [[817  46   0   0]
#  [  4 805  27   0]
#  [  1  32 739  46]
#  [  0   1  39 863]]
#               precision    recall  f1-score   support
#
#            1       0.99      0.95      0.97       863
#            2       0.91      0.96      0.94       836
#            3       0.92      0.90      0.91       818
#            4       0.95      0.96      0.95       903
#
#     accuracy                           0.94      3420
#    macro avg       0.94      0.94      0.94      3420
# weighted avg       0.94      0.94      0.94      3420

# %%
# Plotting AUC ROC for SVC
plot_ROC_curve(svc,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for SVC'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={1: 'Price range 1', 2: 'Price range 2', 3: 'Price range 3',
#                 4: 'Price range 4'},
#        estimator=SVC(probability=True))

# %%
# Using KNN
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
predknn=knn.predict(X_test)
predtrain=knn.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predknn))
print(confusion_matrix(Y_test,predknn))
print(classification_report(Y_test,predknn))
# Out:
# Training accuracy is  0.9675343667739105
# 0.9552631578947368
# [[840  23   0   0]
#  [  4 781  50   1]
#  [  0  23 764  31]
#  [  0   0  21 882]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.97      0.98       863
#            2       0.94      0.93      0.94       836
#            3       0.91      0.93      0.92       818
#            4       0.96      0.98      0.97       903
#
#     accuracy                           0.96      3420
#    macro avg       0.95      0.95      0.95      3420
# weighted avg       0.96      0.96      0.96      3420

# %%
# Plotting AUC ROC for KNN
plot_ROC_curve(knn,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for KNeighborsClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={1: 'Price range 1', 2: 'Price range 2', 3: 'Price range 3',
#                 4: 'Price range 4'},
#        estimator=KNeighborsClassifier())

# %%
# Using GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier
xgb=GradientBoostingClassifier()
xgb.fit(X_train,Y_train)
predxgb=xgb.predict(X_test)
predtrain=knn.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predxgb))
print(confusion_matrix(Y_test,predxgb))
print(classification_report(Y_test,predxgb))
# Out:
# Training accuracy is  0.9675343667739105
# 0.9681286549707603
# [[863   0   0   0]
#  [  6 825   5   0]
#  [  0  35 760  23]
#  [  0   0  40 863]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00       863
#            2       0.96      0.99      0.97       836
#            3       0.94      0.93      0.94       818
#            4       0.97      0.96      0.96       903
#
#     accuracy                           0.97      3420
#    macro avg       0.97      0.97      0.97      3420
# weighted avg       0.97      0.97      0.97      3420

# %%
# Plotting AUC ROC for Decision Tree Classifier
plot_ROC_curve(xgb,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for GradientBoostingClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={1: 'Price range 1', 2: 'Price range 2', 3: 'Price range 3',
#                 4: 'Price range 4'},
#        estimator=GradientBoostingClassifier())

# %%
# Using Naive bayes (GaussianNB)
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, Y_train)
predgnb = gnb.predict(X_test)
predtrain=gnb.predict(X_train)
print("Training accuracy is ",accuracy_score(Y_train,predtrain))
print(accuracy_score(Y_test,predgnb))
print(confusion_matrix(Y_test,predgnb))
print(classification_report(Y_test,predgnb))
# Out:
# Training accuracy is  0.5949107926294238
# 0.5926900584795322
# [[847  12   2   2]
#  [576 168  87   5]
#  [149 111 534  24]
#  [ 73   9 343 478]]
#               precision    recall  f1-score   support
#
#            1       0.51      0.98      0.68       863
#            2       0.56      0.20      0.30       836
#            3       0.55      0.65      0.60       818
#            4       0.94      0.53      0.68       903
#
#     accuracy                           0.59      3420
#    macro avg       0.64      0.59      0.56      3420
# weighted avg       0.65      0.59      0.56      3420

# %%
# Plotting AUC ROC for Decision Tree Classifier
plot_ROC_curve(gnb,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for GaussianNB'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={1: 'Price range 1', 2: 'Price range 2', 3: 'Price range 3',
#                 4: 'Price range 4'},
#        estimator=GaussianNB())

# %%
from sklearn.model_selection import cross_val_score

# validation accuracy

model=[lg,dtc,rf,knn,xgb,gnb,svc]

for i in model:
    for j in range(2,11):
        print('taking cv =', j)
        cr_score=cross_val_score(i, X, Y, cv=j)
        print('Cross validation score for ' , i ,' is', cr_score)
        print('Mean of Cross Val. score is ', cr_score.mean())
# Out:
# taking cv = 2
# Cross validation score for  LogisticRegression()  is [0.89412728 0.91740758]
# Mean of Cross Val. score is  0.9057674309780066
# taking cv = 3
# Cross validation score for  LogisticRegression()  is [0.88717319 0.91507282 0.91330291]
# Mean of Cross Val. score is  0.9051829737915016
# taking cv = 4
# Cross validation score for  LogisticRegression()  is [0.87973795 0.91109031 0.92185307 0.90781469]
# Mean of Cross Val. score is  0.9051240056153486
# taking cv = 5
# Cross validation score for  LogisticRegression()  is [0.87923977 0.89616847 0.91664229 0.91927464 0.91050015]
# Mean of Cross Val. score is  0.904365063482534
# taking cv = 6
# Cross validation score for  LogisticRegression()  is [0.87157895 0.9        0.91224991 0.91751492 0.91716392 0.90803791]
# Mean of Cross Val. score is  0.904424267055846
# taking cv = 7
# Cross validation score for  LogisticRegression()  is [0.8751535  0.88661482 0.91072891 0.91850942 0.91809992 0.91482391
#  0.90704341]
# ...

# %% [markdown]
# **Concluding remark**
# 1. As we can see that Random forest Classifier is giving an accuracy of 99% which is greater than all other
# 2. At fold 10 compared with all other classifier Random forest classifier showing cross val score of 96.20% which is quite good
# 3. hence selecting the best model as random forest classifier

# %% [markdown]
# **Hyperparameter Tunning**

# %%
from sklearn.model_selection import GridSearchCV

#Creating parameter list to be passed in GridSearchCV
parameters = {
    'n_estimators':[50,100],
    'criterion':['gini','entropty'],
    'max_features':['auto','log2','sqrt'],
    'max_depth':[5,10]
 
} 

GCV=GridSearchCV(estimator=RandomForestClassifier(),
                param_grid=parameters,
                cv=16,
                scoring='accuracy')

GCV.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=16, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropty'],
#                          'max_depth': [5, 10],
#                          'max_features': ['auto', 'log2', 'sqrt'],
#                          'n_estimators': [50, 100]},
#              scoring='accuracy')

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 10,
#  'max_features': 'log2',
#  'n_estimators': 100}

# %%
# Checking score with best parameter
final_model=RandomForestClassifier(criterion='gini',max_depth=10,max_features='log2',n_estimators=100)
final_model.fit(X_train,Y_train)
predfinal=final_model.predict(X_test)
print('Final Accuracy is with Random Forest Classifier = ',accuracy_score(Y_test,predfinal))
# Out:
# Final Accuracy is with Random Forest Classifier =  0.9713450292397661

# %%
# Plotting AUC ROC for Final Model
plot_ROC_curve(final_model,X_train, Y_train, X_test, Y_test)
# Out:
# ROCAUC(ax=<AxesSubplot:title={'center':'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>,
#        encoder={1: 'Price range 1', 2: 'Price range 2', 3: 'Price range 3',
#                 4: 'Price range 4'},
#        estimator=RandomForestClassifier(max_depth=10, max_features='log2'))

# %%
GCV.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10, max_features='log2')

# %% [markdown]
# **Finalizing the earlier model which was giving accuracy of 99%**

# %%
#Importing Job lib for saving the model
import joblib
joblib.dump(RandomForestClassifier(), "Zomato Price range prediction.pkl")
# Out:
# ['Zomato Price range prediction.pkl']

# %%
# Conclusion Step 
a=np.array(Y_test)
df_con=pd.DataFrame({'Original':a,'Predicted':predrf}, index=range(len(a)))
df_con
# Out:
#       Original  Predicted
# 0            2          2
# 1            3          3
# 2            4          4
# 3            4          4
# 4            2          2
# ...        ...        ...
# 3415         3          3
# 3416         1          1
# 3417         4          4
# 3418         4          4
# 3419         1          1
#
# [3420 rows x 2 columns]

# %% [markdown]
# **END**
